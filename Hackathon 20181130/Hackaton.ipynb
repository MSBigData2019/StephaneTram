# %% [markdown]
# # Comment fabriquer le hit de 2019?

# %% [markdown]
# ## I  - Définir les caractéristiques d'un hit

# %% [markdown]
# ### Scoring

# %% [markdown]
# ### Caractéristiques d'une chanson

# %% [markdown]
# ### Caractéristiques d'un artiste

# %% [markdown]
# ### Vecteurs de diffusion

# %% [markdown]
# ### Saisonnalité

# %% [markdown]
# ## II - Démarche

# %% [markdown]
# ### Exploration d'API

# %% [markdown]
# ### Exploration de sources

# %% [markdown]
# ### Existant

# %% [markdown]
# ## III - Extraction de données

# %%
import requests
import spotify_token as st
#data = st.start_session("therondcharles@gmail.com","viking59")
data = st.start_session("stephane.tram@gmail.com","gkbu50v-")
access_token = data[0]
expiration_date = data[1]
#access_token="BQBa2KiSG8LxQ43piBcr6M64C3Rz5bOcQQCb7FkCoDL7Ba5av6zJ1Q73iMCEdAKmChs_n3-wjiJdmd1BWTgT3wh2nR61EjzYkFijYG-VfzkKA2GQhOrMIgxcV893d-DcJ89mgZKtzwJku5VuvDZ59szUrIb9DlOMjNBBNTFDBwMoXNeuXkuNfycO3wtr5Q"
myhead = {'Authorization': 'Bearer {}'.format(access_token)}

df=pd.DataFrame(columns=['song_name','song_id','artist_name','artist_id'])
PP=["37i9dQZEVXbMDoHDwVN2tF","37i9dQZF1DWVuV87wUBNwc","5bPovYKNF7itzq7KLp84fF","4RgTljORFKfmWBLfjm1Jz4","6UHU5K1lNJKLBtNkYah9vr"]
for playlist in PP:
    response = requests.get("https://api.spotify.com/v1/playlists/"+str(playlist)+"/tracks"  , headers=myhead)
    #print(response.content)
    tab=json.loads(response.content)['items']
    for row in tab:
        print("==============================")

        tab2 = row['track']['artists']
        for row2 in tab2:



            response = requests.get("https://api.spotify.com/v1/artists/"+str(row2['id'])+"/top-tracks?country=FR"  , headers=myhead)
            tab3=json.loads(response.content)['tracks']
            for row3 in tab3:
                song_dic={}
                song_dic['song_name']=row3['name']

                song_dic['song_id']=row3['id']
                song_dic['artist_name']=row2['name']
                song_dic['artist_id']=row2['id']

                song_dic['artist_popuplarity']=spotify.artist(row2['id'])['popularity']
                song_dic['song_popuplarity']=row3['popularity']


                if df.query("song_id=='"+str(row3['id'])+"' & artist_id=='"+str(row2['id'])+"'").song_id.count()==0:
                    print("add",row2['name'],row3['name'])
                    print('-------------------------------')
                    querry_id = spotify.audio_features(row3['id'])
                    #print(querry_id[0]['tempo'])
                    song_dic['duration_ms'] = querry_id[0]['tempo']
                    song_dic['key']  = querry_id[0]['key']
                    song_dic['mode']  = querry_id[0]['mode']
                    song_dic['time_signature']  = querry_id[0]['time_signature']
                    song_dic['acousticness']  = querry_id[0]['acousticness']
                    song_dic['danceability']  = querry_id[0]['danceability']
                    song_dic['energy'] = querry_id[0]['energy']
                    song_dic['instrumentalness'] = querry_id[0]['instrumentalness']
                    song_dic['liveness'] = querry_id[0]['liveness']
                    song_dic['loudness'] = querry_id[0]['loudness']
                    song_dic['speechiness'] = querry_id[0]['speechiness']
                    song_dic['valence'] = querry_id[0]['valence']
                    song_dic['tempo'] = querry_id[0]['tempo']
                    df = df.append([song_dic],ignore_index=True)
# Out:
# ==============================
# add Ariana Grande thank u, next
# -------------------------------
# add Ariana Grande breathin
# -------------------------------
# C:\Users\sebas\Anaconda3\lib\site-packages\pandas\core\frame.py:6211: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   sort=sort)
# add Ariana Grande God is a woman
# -------------------------------
# add Ariana Grande no tears left to cry
# -------------------------------
# add Ariana Grande Santa Tell Me
# -------------------------------
# add Ariana Grande Side To Side
# -------------------------------
# add Ariana Grande Into You
# -------------------------------
# add Ariana Grande One Last Time
# -------------------------------
# add Ariana Grande sweetener
# -------------------------------
# add Ariana Grande everytime
# -------------------------------
# ==============================
# add DJ Snake Taki Taki (with Selena Gomez, Ozuna & Cardi B)
# -------------------------------
# add DJ Snake Let Me Love You
# -------------------------------
# add DJ Snake Creep On Me
# -------------------------------
# add DJ Snake Middle
# -------------------------------
# add DJ Snake A Different Way (with Lauv)
# -------------------------------
# add DJ Snake Magenta Riddim
# -------------------------------
# add DJ Snake Lean On (feat. MØ & DJ Snake)
# -------------------------------
# add DJ Snake Turn Down for What
# -------------------------------
# add DJ Snake You Know You Like It
# -------------------------------
# add DJ Snake Let's Get Ill
# -------------------------------
# add Selena Gomez Taki Taki (with Selena Gomez, Ozuna & Cardi B)
# -------------------------------
# add Selena Gomez Back To You - From 13 Reasons Why – Season 2 Soundtrack
# -------------------------------
# add Selena Gomez Wolves
# -------------------------------
# add Selena Gomez It Ain't Me (with Selena Gomez)
# -------------------------------
# add Selena Gomez Bad Liar
# -------------------------------
# add Selena Gomez Fetish (feat. Gucci Mane)
# -------------------------------
# add Selena Gomez The Heart Wants What It Wants
# -------------------------------
# add Selena Gomez Kill Em With Kindness
# -------------------------------
# add Selena Gomez Hands To Myself
# -------------------------------
# add Selena Gomez Same Old Love
# -------------------------------
# add Ozuna Taki Taki (with Selena Gomez, Ozuna & Cardi B)
# -------------------------------
# add Ozuna Imposible
# -------------------------------
# add Ozuna Vaina Loca
# -------------------------------
# add Ozuna Ibiza
# -------------------------------
# add Ozuna Asesina - Remix
# -------------------------------
# add Ozuna Me Dijeron
# -------------------------------
# add Ozuna Criminal
# -------------------------------
# add Ozuna Solita
# -------------------------------
# add Ozuna Síguelo Bailando
# -------------------------------
# add Ozuna Se Preparó
# -------------------------------
# add Cardi B I Like It
# -------------------------------
# add Cardi B Money
# -------------------------------
# add Cardi B Finesse (Remix) [feat. Cardi B]
# -------------------------------
# add Cardi B MotorSport
# -------------------------------
# add Cardi B Bodak Yellow
# -------------------------------
# add Cardi B Backin' It Up (feat. Cardi B)
# -------------------------------
# add Cardi B Ring (feat. Kehlani)
# -------------------------------
# add Cardi B Bartier Cardi (feat. 21 Savage)
# -------------------------------
# add Cardi B Be Careful
# -------------------------------
# add Cardi B Drip (feat. Migos)
# -------------------------------
# ==============================
# add Bad Bunny MIA (feat. Drake)
# -------------------------------
# add Bad Bunny I Like It
# -------------------------------
# add Bad Bunny Te Boté - Remix
# -------------------------------
# add Bad Bunny Está Rico
# -------------------------------
# add Bad Bunny Estamos Bien
# -------------------------------
# add Bad Bunny Madura (feat. Bad Bunny)
# -------------------------------
# add Bad Bunny Loca Remix
# -------------------------------
# add Bad Bunny Te Guste
# -------------------------------
# add Bad Bunny Triste
# -------------------------------
# add Bad Bunny Mayores
# -------------------------------
# add Drake In My Feelings
# -------------------------------
# add Drake Nonstop
# -------------------------------
# add Drake God's Plan
# -------------------------------
# add Drake Never Recover (Lil Baby & Gunna, Drake)
# -------------------------------
# add Drake Yes Indeed
# -------------------------------
# add Drake Nice For What
# -------------------------------
# add Drake Look Alive (feat. Drake)
# -------------------------------
# add Drake Don’t Matter To Me (with Michael Jackson)
# -------------------------------
# add Drake One Dance
# -------------------------------
# add Drake Mob Ties
# -------------------------------
# ==============================
# add 6ix9ine BEBE
# -------------------------------
# add 6ix9ine FEFE (feat. Nicki Minaj & Murda Beatz)
# -------------------------------
# add 6ix9ine STOOPID
# -------------------------------
# add 6ix9ine BILLY
# -------------------------------
# add 6ix9ine TATI
# -------------------------------
# add 6ix9ine GOTTI
# -------------------------------
# add 6ix9ine GUMMO
# -------------------------------
# add 6ix9ine KIKA (feat. Tory Lanez)
# -------------------------------
# add 6ix9ine MAMA (feat. Nicki Minaj, Kanye West)
# -------------------------------
# add 6ix9ine Poles 1469
# -------------------------------
# add Tory Lanez FeRRis WhEEL (feat. Trippie Redd)
# -------------------------------
# add Tory Lanez TAlk tO Me (with Rich The Kid)
# -------------------------------
# add Tory Lanez DrIP DrIp Drip (feat. Meek Mill)
# -------------------------------
# add Tory Lanez MiAMi (feat. Gunna)
# -------------------------------
# add Tory Lanez FlEXiBle (feat. Chris Brown & Lil Baby)
# -------------------------------
# add Tory Lanez Pa Mi (with Ozuna)
# -------------------------------
# add Tory Lanez Shooters
# -------------------------------
# add Tory Lanez Why DON'T You LOVE me?
# -------------------------------
# add Tory Lanez Say It
# -------------------------------
# add Tory Lanez Miss You (with Major Lazer & Tory Lanez)
# -------------------------------
# ==============================
# add Lil Baby Drip Too Hard (Lil Baby & Gunna)
# -------------------------------
# add Lil Baby Never Recover (Lil Baby & Gunna, Drake)
# -------------------------------
# add Lil Baby Yes Indeed
# -------------------------------
# add Lil Baby Close Friends (Lil Baby & Gunna)
# -------------------------------
# add Lil Baby Life Goes On
# -------------------------------
# add Lil Baby Freestyle
# -------------------------------
# add Lil Baby Off White VLONE (Lil Baby & Gunna feat. Lil Durk & NAV)
# -------------------------------
# add Lil Baby Business Is Business (Lil Baby & Gunna)
# -------------------------------
# add Lil Baby I Am (Lil Baby & Gunna)
# -------------------------------
# add Lil Baby Belly (Lil Baby & Gunna)
# -------------------------------
# ==============================
# add Halsey Without Me
# -------------------------------
# add Halsey Eastside (with Halsey & Khalid)
# -------------------------------
# add Halsey Him & I (with Halsey)
# -------------------------------
# add Halsey Bad At Love
# -------------------------------
# add Halsey Sorry
# -------------------------------
# add Halsey Now Or Never
# -------------------------------
# add Halsey Gasoline
# -------------------------------
# add Halsey Alone (Calvin Harris Remix) (Feat. Stefflon Don)
# -------------------------------
# add Halsey Colors
# -------------------------------
# add Halsey Alone (Feat. Big Sean & Stefflon Don)
# -------------------------------
# ==============================
# add Nicki Minaj Woman Like Me (feat. Nicki Minaj)
# -------------------------------
# add Nicki Minaj Dip (feat. Nicki Minaj)
# -------------------------------
# add Nicki Minaj MotorSport
# -------------------------------
# add Nicki Minaj Swalla (feat. Nicki Minaj & Ty Dolla $ign)
# -------------------------------
# add Nicki Minaj Bang Bang
# -------------------------------
# add Nicki Minaj Bed (feat. Ariana Grande)
# -------------------------------
# add Nicki Minaj Barbie Dreams
# -------------------------------
# add Nicki Minaj Chun-Li
# -------------------------------
# add Nicki Minaj Majesty (with Labrinth & feat. Eminem)
# -------------------------------
# add Nicki Minaj Runnin (with A$AP Rocky, A$AP Ferg & Nicki Minaj)
# -------------------------------
# add Kanye West I Love It (& Lil Pump)
# -------------------------------
# add Kanye West FourFiveSeconds
# -------------------------------
# add Kanye West Gold Digger
# -------------------------------
# add Kanye West POWER
# -------------------------------
# add Kanye West Stronger
# -------------------------------
# add Kanye West Black Skinhead
# -------------------------------
# add Kanye West All Mine
# -------------------------------
# add Kanye West Heartless
# -------------------------------
# add Kanye West Famous
# -------------------------------
# add Kanye West All Of The Lights
# -------------------------------
# ==============================
# add Marshmello Happier
# -------------------------------
# add Marshmello FRIENDS
# -------------------------------
# add Marshmello Silence
# -------------------------------
# add Marshmello Wolves
# -------------------------------
# add Marshmello Everyday
# -------------------------------
# add Marshmello Spotlight
# -------------------------------
# add Marshmello Alone
# -------------------------------
# add Marshmello Danger (with Migos & Marshmello)
# -------------------------------
# add Marshmello You Can Cry
# -------------------------------
# add Marshmello Keep It Mello (feat. Omar LinX)
# -------------------------------
# add Bastille Happier
# -------------------------------
# add Bastille Quarter Past Midnight
# -------------------------------
# add Bastille Pompeii
# -------------------------------
# add Bastille World Gone Mad
# -------------------------------
# add Bastille Happier - Breathe Carolina Remix
# -------------------------------
# add Bastille Happier - Stripped
# -------------------------------
# add Bastille Good Grief
# -------------------------------
# add Bastille Of The Night
# -------------------------------
# add Bastille Oblivion
# -------------------------------
# add Bastille Send Them Off!
# -------------------------------
# ==============================
# add Travis Scott SICKO MODE
# -------------------------------
# add Travis Scott STARGAZING
# -------------------------------
# add Travis Scott goosebumps
# -------------------------------
# add Travis Scott YOSEMITE
# -------------------------------
# add Travis Scott BUTTERFLY EFFECT
# -------------------------------
# add Travis Scott CAN'T SAY
# -------------------------------
# add Travis Scott WAKE UP
# -------------------------------
# add Travis Scott NO BYSTANDERS
# -------------------------------
# add Travis Scott STOP TRYING TO BE GOD
# -------------------------------
# add Travis Scott R.I.P. SCREW
# -------------------------------
# ==============================
# add Kodak Black ZEZE (feat. Travis Scott & Offset)
# -------------------------------
# add Kodak Black Wake Up in the Sky
# -------------------------------
# add Kodak Black Roll In Peace (feat. XXXTENTACION)
# -------------------------------
# add Kodak Black Take One
# -------------------------------
# add Kodak Black Drowning (feat. Kodak Black)
# -------------------------------
# add Kodak Black Codeine Dreaming (feat. Lil Wayne)
# -------------------------------
# add Kodak Black If I'm Lyin, I'm Flyin
# -------------------------------
# add Kodak Black Tunnel Vision
# -------------------------------
# add Kodak Black Transportin'
# -------------------------------
# add Kodak Black No Flockin
# -------------------------------
# add Offset Ric Flair Drip (& Metro Boomin)
# -------------------------------
# add Offset Ghostface Killers
# -------------------------------
# add Offset Rap Saved Me
# -------------------------------
# add Offset Alive (with Offset & 2 Chainz)
# -------------------------------
# add Offset Met Gala (feat. Offset)
# -------------------------------
# add Offset Pray For The Drip (feat. Offset)
# -------------------------------
# add Offset Mad Stalkers
# -------------------------------
# add Offset Nightmare
# -------------------------------
# add Offset Disrespectful
# -------------------------------
# add Offset Still Serving
# -------------------------------
# ==============================
# add Post Malone Sunflower - Spider-Man: Into the Spider-Verse
# -------------------------------
# add Post Malone Better Now
# -------------------------------
# add Post Malone rockstar (feat. 21 Savage)
# -------------------------------
# add Post Malone Psycho (feat. Ty Dolla $ign)
# -------------------------------
# add Post Malone I Fall Apart
# -------------------------------
# add Post Malone Congratulations
# -------------------------------
# add Post Malone Candy Paint
# -------------------------------
# add Post Malone Ball For Me (feat. Nicki Minaj)
# -------------------------------
# add Post Malone Go Flex
# -------------------------------
# add Post Malone Stay
# -------------------------------
# add Swae Lee Sunflower - Spider-Man: Into the Spider-Verse
# -------------------------------
# add Swae Lee Arms Around You (feat. Maluma & Swae Lee)
# -------------------------------
# add Swae Lee Close To Me (with Diplo) (feat. Swae Lee)
# -------------------------------
# add Swae Lee Unforgettable
# -------------------------------
# add Swae Lee Powerglide (feat. Juicy J) - From SR3MM
# -------------------------------
# add Swae Lee Hopeless Romantic (feat. Swae Lee)
# -------------------------------
# add Swae Lee Real Friends
# -------------------------------
# add Swae Lee Guatemala - From Swaecation
# -------------------------------
# add Swae Lee The Ways (with Swae Lee)
# -------------------------------
# add Swae Lee CLOSE (feat. Travis Scott) - From SR3MM
# -------------------------------
# ==============================
# add Lady Gaga Shallow
# -------------------------------
# add Lady Gaga Always Remember Us This Way
# -------------------------------
# add Lady Gaga Million Reasons
# -------------------------------
# add Lady Gaga I'll Never Love Again - Film Version - Radio Edit
# -------------------------------
# add Lady Gaga Music To My Eyes
# -------------------------------
# add Lady Gaga Look What I Found
# -------------------------------
# add Lady Gaga I'll Never Love Again - Extended Version
# -------------------------------
# add Lady Gaga Is That Alright?
# -------------------------------
# add Lady Gaga Diggin' My Grave
# -------------------------------
# add Lady Gaga Heal Me
# -------------------------------
# add Bradley Cooper Shallow
# -------------------------------
# add Bradley Cooper I'll Never Love Again - Film Version - Radio Edit
# -------------------------------
# add Bradley Cooper Music To My Eyes
# -------------------------------
# add Bradley Cooper Maybe It's Time
# -------------------------------
# add Bradley Cooper Diggin' My Grave
# -------------------------------
# add Bradley Cooper I Don't Know What Love Is
# -------------------------------
# add Bradley Cooper Black Eyes
# -------------------------------
# add Bradley Cooper Out Of Time
# -------------------------------
# add Bradley Cooper Alibi
# -------------------------------
# add Bradley Cooper Too Far Gone
# -------------------------------
# ==============================
# add XXXTENTACION Arms Around You (feat. Maluma & Swae Lee)
# -------------------------------
# add XXXTENTACION SAD!
# -------------------------------
# add XXXTENTACION Moonlight
# -------------------------------
# add XXXTENTACION BAD!
# -------------------------------
# add XXXTENTACION Jocelyn Flores
# -------------------------------
# add XXXTENTACION Falling Down - Bonus Track
# -------------------------------
# add XXXTENTACION changes
# -------------------------------
# add XXXTENTACION Fuck Love (feat. Trippie Redd)
# -------------------------------
# add XXXTENTACION Everybody Dies In Their Nightmares
# -------------------------------
# add XXXTENTACION the remedy for a broken heart (why am I so in love)
# -------------------------------
# add Lil Pump Arms Around You (feat. Maluma & Swae Lee)
# -------------------------------
# add Lil Pump I Love It (& Lil Pump)
# -------------------------------
# add Lil Pump Esskeetit
# -------------------------------
# add Lil Pump Gucci Gang
# -------------------------------
# add Lil Pump Welcome to the Party (with French Montana & Lil Pump, feat. Zhavia Ward) - from Deadpool 2
# -------------------------------
# add Lil Pump Drug Addicts
# -------------------------------
# add Lil Pump Multi Millionaire (feat. Lil Uzi Vert)
# -------------------------------
# add Lil Pump Jettski Grizzley (feat. Lil Pump)
# -------------------------------
# add Lil Pump Boss
# -------------------------------
# add Lil Pump Bitches On Bitches (feat. Lil Pump)
# -------------------------------
# add Maluma Amigos Con Derechos
# -------------------------------
# add Maluma Mala Mía
# -------------------------------
# add Maluma Clandestino
# -------------------------------
# add Maluma Créeme
# -------------------------------
# add Maluma Felices los 4
# -------------------------------
# add Maluma Corazón (feat. Nego do Borel)
# -------------------------------
# add Maluma El Préstamo
# -------------------------------
# add Maluma Bella - Remix
# -------------------------------
# add Maluma Marinero
# -------------------------------
# add Maluma Borro Cassette
# -------------------------------
# ==============================
# add Anuel Aa Quiere Beber
# -------------------------------
# add Anuel Aa Culpables
# -------------------------------
# add Anuel Aa Ella Quiere Beber - Remix
# -------------------------------
# add Anuel Aa Bubalu
# -------------------------------
# add Anuel Aa Hipócrita
# -------------------------------
# add Anuel Aa Adictiva
# -------------------------------
# add Anuel Aa Brindemos
# -------------------------------
# add Anuel Aa Sola (Remix) [feat. Daddy Yankee, Wisin, Farruko, Zion & Lennox]
# -------------------------------
# add Anuel Aa Pensando en Ti
# -------------------------------
# add Anuel Aa Yeezy
# -------------------------------
# ==============================
# add Sheck Wes Mo Bamba
# -------------------------------
# add Sheck Wes Live Sheck Wes
# -------------------------------
# add Sheck Wes Gmail
# -------------------------------
# add Sheck Wes Chippi Chippi
# -------------------------------
# add Sheck Wes Do That
# -------------------------------
# add Sheck Wes Kyrie
# -------------------------------
# add Sheck Wes Wanted
# -------------------------------
# add Sheck Wes Mindfucker
# -------------------------------
# add Sheck Wes Burn Slow - Interlude
# -------------------------------
# add Sheck Wes Fuck Everybody
# -------------------------------
# ==============================
# add Billie Eilish when the party's over
# -------------------------------
# add Billie Eilish lovely (with Khalid)
# -------------------------------
# add Billie Eilish idontwannabeyouanymore
# -------------------------------
# add Billie Eilish come out and play
# -------------------------------
# add Billie Eilish ocean eyes
# -------------------------------
# add Billie Eilish you should see me in a crown
# -------------------------------
# add Billie Eilish bellyache
# -------------------------------
# add Billie Eilish bitches broken hearts
# -------------------------------
# add Billie Eilish my boy
# -------------------------------
# add Billie Eilish COPYCAT
# -------------------------------
# ==============================
# add Ava Max Sweet but Psycho
# -------------------------------
# add Ava Max Make Up (feat. Ava Max)
# -------------------------------
# add Ava Max Into Your Arms (feat. Ava Max)
# -------------------------------
# add Ava Max Not Your Barbie Girl
# -------------------------------
# add Ava Max My Way
# -------------------------------
# add Ava Max Clap Your Hands (feat. Ava Max)
# -------------------------------
# add Ava Max Sweet but Psycho - Acoustic
# -------------------------------
# add Ava Max Sweet but Psycho - Paul Morrell Remix
# -------------------------------
# add Ava Max Into Your Arms (feat. Ava Max) - BEAUZ Remix
# -------------------------------
# add Ava Max My Way - Shew Remix
# -------------------------------
# ==============================
# add A Boogie Wit da Hoodie Drowning (feat. Kodak Black)
# -------------------------------
# add A Boogie Wit da Hoodie KEKE
# -------------------------------
# add A Boogie Wit da Hoodie Pull Up (feat. NAV)
# -------------------------------
# add A Boogie Wit da Hoodie My Shit
# -------------------------------
# add A Boogie Wit da Hoodie Horses (with PnB Rock, Kodak Black & A Boogie Wit da Hoodie)
# -------------------------------
# add A Boogie Wit da Hoodie Still Think About You
# -------------------------------
# add A Boogie Wit da Hoodie Beast Mode (feat. PnB Rock & YoungBoy Never Broke Again)
# -------------------------------
# add A Boogie Wit da Hoodie Jungle
# -------------------------------
# add A Boogie Wit da Hoodie Say A'
# -------------------------------
# add A Boogie Wit da Hoodie Lovin' (feat. A Boogie Wit da Hoodie)
# -------------------------------
# ==============================
# add Paulo Londra Cuando Te Besé
# -------------------------------
# add Paulo Londra Adan y Eva
# -------------------------------
# add Paulo Londra Chica Paranormal
# -------------------------------
# add Paulo Londra Nena Maldicion (feat. Lenny Tavarez)
# -------------------------------
# add Paulo Londra Te Amo
# -------------------------------
# add Paulo Londra Dimelo
# -------------------------------
# add Paulo Londra Condenado Para el Millon
# -------------------------------
# add Paulo Londra Me Tiene Mal
# -------------------------------
# add Paulo Londra Cámara Lenta
# -------------------------------
# add Paulo Londra Luna Llena
# -------------------------------
# ==============================
# add Queen Bohemian Rhapsody - Remastered 2011
# -------------------------------
# add Queen Don't Stop Me Now - Remastered
# -------------------------------
# add Queen Another One Bites The Dust - Remastered 2011
# -------------------------------
# add Queen Under Pressure - Remastered
# -------------------------------
# add Queen We Will Rock You - Remastered
# -------------------------------
# add Queen Somebody To Love - Remastered 2011
# -------------------------------
# add Queen We Are The Champions - Remastered 2011
# -------------------------------
# add Queen I Want To Break Free - Single Remix
# -------------------------------
# add Queen Radio Ga Ga - Live Aid
# -------------------------------
# add Queen Love Of My Life - Remastered 2011
# -------------------------------
# ==============================
# add Mariah Carey All I Want for Christmas Is You
# -------------------------------
# add Mariah Carey Christmas (Baby Please Come Home)
# -------------------------------
# add Mariah Carey Always Be My Baby
# -------------------------------
# add Mariah Carey We Belong Together
# -------------------------------
# add Mariah Carey Caution
# -------------------------------
# add Mariah Carey Hero
# -------------------------------
# add Mariah Carey O Holy Night
# -------------------------------
# add Mariah Carey All I Want For Christmas Is You (SuperFestive!) Duet with Mariah Carey
# -------------------------------
# add Mariah Carey GTFO
# -------------------------------
# add Mariah Carey Fantasy
# -------------------------------
# ==============================
# add Khalid Eastside (with Halsey & Khalid)
# -------------------------------
# add Khalid lovely (with Khalid)
# -------------------------------
# add Khalid Better
# -------------------------------
# add Khalid Love Lies (with Normani)
# -------------------------------
# add Khalid Ocean (feat. Khalid)
# -------------------------------
# add Khalid Suncity (feat. Empress Of)
# -------------------------------
# add Khalid Young Dumb & Broke
# -------------------------------
# add Khalid Silence
# -------------------------------
# add Khalid OTW
# -------------------------------
# add Khalid Saturday Nights
# -------------------------------
# ==============================
# add Gunna Drip Too Hard (Lil Baby & Gunna)
# -------------------------------
# add Gunna Never Recover (Lil Baby & Gunna, Drake)
# -------------------------------
# add Gunna Sold Out Dates (feat. Lil Baby)
# -------------------------------
# add Gunna Off White VLONE (Lil Baby & Gunna feat. Lil Durk & NAV)
# -------------------------------
# add Gunna Business Is Business (Lil Baby & Gunna)
# -------------------------------
# add Gunna I Am (Lil Baby & Gunna)
# -------------------------------
# add Gunna Marvelous Day (feat. Lil Uzi Vert & Gunna)
# -------------------------------
# add Gunna Belly (Lil Baby & Gunna)
# -------------------------------
# add Gunna Do You Understand? (feat. Gunna & Tory Lanez)
# -------------------------------
# add Gunna World Is Yours (Lil Baby & Gunna)
# -------------------------------
# ==============================
# add benny blanco Eastside (with Halsey & Khalid)
# -------------------------------
# add benny blanco I Found You (with Calvin Harris)
# -------------------------------
# add benny blanco Eastside (with Halsey & Khalid) - Acoustic
# -------------------------------
# add benny blanco Somebody to Love - Remix
# -------------------------------
# add benny blanco Don't Wait - Benny Blanco Remix
# -------------------------------
# add benny blanco Ain't No Sunshine - Benny Blanco Remix
# -------------------------------
# add benny blanco LOOSE
# -------------------------------
# add benny blanco SHAKE THAT
# -------------------------------
# add benny blanco B-O-O-T-A-Y
# -------------------------------
# add benny blanco PU$$Y
# -------------------------------
# ==============================
# add Maroon 5 Girls Like You (feat. Cardi B)
# -------------------------------
# add Maroon 5 What Lovers Do (feat. SZA)
# -------------------------------
# add Maroon 5 She Will Be Loved - Radio Mix
# -------------------------------
# add Maroon 5 Sugar
# -------------------------------
# add Maroon 5 This Love
# -------------------------------
# add Maroon 5 Maps
# -------------------------------
# add Maroon 5 Payphone
# -------------------------------
# add Maroon 5 Don't Wanna Know (feat. Kendrick Lamar)
# -------------------------------
# add Maroon 5 Girls Like You
# -------------------------------
# add Maroon 5 Moves Like Jagger - Studio Recording From The Voice Performance
# -------------------------------
# ==============================
# ==============================
# add Juice WRLD Lucid Dreams
# -------------------------------
# add Juice WRLD Armed And Dangerous
# -------------------------------
# add Juice WRLD Fine China
# -------------------------------
# add Juice WRLD All Girls Are The Same
# -------------------------------
# add Juice WRLD Lean Wit Me
# -------------------------------
# add Juice WRLD Legends
# -------------------------------
# add Juice WRLD Hard Work Pays Off
# -------------------------------
# add Juice WRLD Black & White
# -------------------------------
# add Juice WRLD Wasted (feat. Lil Uzi Vert)
# -------------------------------
# add Juice WRLD Jet Lag (feat. Young Scooter)
# -------------------------------
# ==============================
# add Murda Beatz Do Not Disturb (feat. Lil Yachty & Offset)
# -------------------------------
# add Murda Beatz 123
# -------------------------------
# add Murda Beatz 420 in London
# -------------------------------
# add Murda Beatz Pray (feat. A$AP Ferg)
# -------------------------------
# add Murda Beatz Pockets
# -------------------------------
# add Murda Beatz Big Dope
# -------------------------------
# add Murda Beatz Wokstar
# -------------------------------
# add Murda Beatz Bumblebee
# -------------------------------
# add Murda Beatz Mayo
# -------------------------------
# add Murda Beatz Good Habits
# -------------------------------
# ==============================
# add Dean Lewis Be Alright
# -------------------------------
# add Dean Lewis Waves
# -------------------------------
# add Dean Lewis Chemicals
# -------------------------------
# add Dean Lewis Lose My Mind
# -------------------------------
# add Dean Lewis Need You Now - Acoustic
# -------------------------------
# add Dean Lewis Let Go
# -------------------------------
# add Dean Lewis Be Alright - Acoustic
# -------------------------------
# add Dean Lewis Lose My Mind - Acoustic
# -------------------------------
# add Dean Lewis Adore
# -------------------------------
# add Dean Lewis Waves - Acoustic
# -------------------------------
# ==============================
# add Dynoro In My Mind
# -------------------------------
# add Dynoro Hangover
# -------------------------------
# add Dynoro Dreaming
# -------------------------------
# add Dynoro Bye Bye Boy - Remix
# -------------------------------
# add Dynoro Einu Iš Proto - Dynoro Remix
# -------------------------------
# add Dynoro Miami Dream - Dynoro Remix
# -------------------------------
# add Gigi D'Agostino In My Mind
# -------------------------------
# add Gigi D'Agostino L'amour Toujours (Small Mix)
# -------------------------------
# add Gigi D'Agostino The Riddle
# -------------------------------
# add Gigi D'Agostino Bla Bla Bla
# -------------------------------
# add Gigi D'Agostino La Passion
# -------------------------------
# add Gigi D'Agostino L'amour Toujours
# -------------------------------
# add Gigi D'Agostino I'll Fly with You - Radio Edit
# -------------------------------
# add Gigi D'Agostino Another Way
# -------------------------------
# add Gigi D'Agostino Ripassa
# -------------------------------
# add Gigi D'Agostino Ininterrottamente
# -------------------------------
# ==============================
# ==============================
# ==============================
# add Calvin Harris Promises (with Sam Smith)
# -------------------------------
# add Calvin Harris One Kiss (with Dua Lipa)
# -------------------------------
# add Calvin Harris I Found You (with Calvin Harris)
# -------------------------------
# add Calvin Harris This Is What You Came For
# -------------------------------
# add Calvin Harris My Way
# -------------------------------
# add Calvin Harris Feels
# -------------------------------
# add Calvin Harris How Deep Is Your Love
# -------------------------------
# add Calvin Harris Summer
# -------------------------------
# add Calvin Harris Checklist (with Calvin Harris) (feat. WizKid)
# -------------------------------
# add Calvin Harris The Weekend - Funk Wav Remix
# -------------------------------
# add Sam Smith Promises (with Sam Smith)
# -------------------------------
# add Sam Smith Too Good At Goodbyes
# -------------------------------
# add Sam Smith Stay With Me
# -------------------------------
# add Sam Smith I'm Not The Only One
# -------------------------------
# add Sam Smith Have Yourself A Merry Little Christmas
# -------------------------------
# add Sam Smith Lay Me Down
# -------------------------------
# add Sam Smith Like I Can
# -------------------------------
# add Sam Smith Make It To Me
# -------------------------------
# add Sam Smith Promises (with Sam Smith) - David Guetta Remix
# -------------------------------
# add Sam Smith Pray
# -------------------------------
# add Jessie Reyez Promises (with Sam Smith)
# -------------------------------
# add Jessie Reyez Nice Guy (with Jessie Reyez)
# -------------------------------
# add Jessie Reyez Figures
# -------------------------------
# add Jessie Reyez Wherever You Go
# -------------------------------
# add Jessie Reyez Figures, a Reprise
# -------------------------------
# add Jessie Reyez Apple Juice
# -------------------------------
# add Jessie Reyez Imported (feat. JRM)
# -------------------------------
# add Jessie Reyez Body Count (feat. Normani & Kehlani) - Remix
# -------------------------------
# add Jessie Reyez Saint Nobody
# -------------------------------
# add Jessie Reyez Pretending (feat. Jessie Reyez)
# -------------------------------
# ==============================
# ==============================
# add Zara Larsson Ruin My Life
# -------------------------------
# add Zara Larsson Never Forget You
# -------------------------------
# add Zara Larsson Lush Life
# -------------------------------
# add Zara Larsson I Can't Fall in Love Without You
# -------------------------------
# add Zara Larsson Ain't My Fault
# -------------------------------
# add Zara Larsson I Would Like
# -------------------------------
# add Zara Larsson Uncover
# -------------------------------
# add Zara Larsson TG4M
# -------------------------------
# add Zara Larsson Sexual - Recorded at Spotify Studios NYC
# -------------------------------
# add Zara Larsson Ain't My Fault - R3hab Remix
# -------------------------------
# ==============================
# add Ellie Goulding Close To Me (with Diplo) (feat. Swae Lee)
# -------------------------------
# add Ellie Goulding Love Me Like You Do - From "Fifty Shades Of Grey"
# -------------------------------
# add Ellie Goulding First Time
# -------------------------------
# add Ellie Goulding How Long Will I Love You - Bonus Track
# -------------------------------
# add Ellie Goulding Burn
# -------------------------------
# add Ellie Goulding On My Mind
# -------------------------------
# add Ellie Goulding Still Falling For You - From "Bridget Jones's Baby"
# -------------------------------
# add Ellie Goulding Your Song - Bonus Track
# -------------------------------
# add Ellie Goulding Vincent
# -------------------------------
# add Ellie Goulding Lights - Single Version
# -------------------------------
# add Diplo Electricity (with Dua Lipa)
# -------------------------------
# add Diplo Close To Me (with Diplo) (feat. Swae Lee)
# -------------------------------
# add Diplo Thunderclouds (with Sia, Diplo & Labrinth)
# -------------------------------
# add Diplo Genius (with Sia, Diplo & Labrinth)
# -------------------------------
# add Diplo Where Are Ü Now (with Justin Bieber)
# -------------------------------
# add Diplo Audio (with Sia, Diplo & Labrinth)
# -------------------------------
# add Diplo Welcome to the Party (with French Montana & Lil Pump, feat. Zhavia Ward) - from Deadpool 2
# -------------------------------
# add Diplo Mountains (with Sia, Diplo & Labrinth)
# -------------------------------
# add Diplo Color Blind
# -------------------------------
# add Diplo Sun In Our Eyes
# -------------------------------
# ==============================
# add Rita Ora Let You Love Me
# -------------------------------
# add Rita Ora Anywhere
# -------------------------------
# add Rita Ora Your Song
# -------------------------------
# add Rita Ora Girls (feat. Cardi B, Bebe Rexha & Charli XCX)
# -------------------------------
# add Rita Ora For You (Fifty Shades Freed)
# -------------------------------
# add Rita Ora Only Want You
# -------------------------------
# add Rita Ora Velvet Rope
# -------------------------------
# add Rita Ora I Will Never Let You Down
# -------------------------------
# add Rita Ora Summer Love
# -------------------------------
# add Rita Ora Body on Me
# -------------------------------
# ==============================
# add Dua Lipa Kiss and Make Up
# -------------------------------
# add Dua Lipa Electricity (with Dua Lipa)
# -------------------------------
# add Dua Lipa One Kiss (with Dua Lipa)
# -------------------------------
# add Dua Lipa IDGAF
# -------------------------------
# add Dua Lipa New Rules
# -------------------------------
# add Dua Lipa Scared to Be Lonely
# -------------------------------
# add Dua Lipa Want To
# -------------------------------
# add Dua Lipa One Kiss (with Dua Lipa) - Oliver Heldens Remix
# -------------------------------
# add Dua Lipa Homesick
# -------------------------------
# add Dua Lipa Be The One
# -------------------------------
# add BLACKPINK Kiss and Make Up
# -------------------------------
# add BLACKPINK DDU-DU DDU-DU
# -------------------------------
# add BLACKPINK As If It's Your Last
# -------------------------------
# add BLACKPINK Forever Young
# -------------------------------
# add BLACKPINK BOOMBAYAH
# -------------------------------
# add BLACKPINK PLAYING WITH FIRE
# -------------------------------
# add BLACKPINK WHISTLE
# -------------------------------
# add BLACKPINK Really
# -------------------------------
# add BLACKPINK See U Later
# -------------------------------
# add BLACKPINK STAY
# -------------------------------
# ==============================
# ==============================
# add Imagine Dragons Bad Liar
# -------------------------------
# add Imagine Dragons Believer
# -------------------------------
# add Imagine Dragons Natural
# -------------------------------
# add Imagine Dragons Thunder
# -------------------------------
# add Imagine Dragons Born To Be Yours
# -------------------------------
# add Imagine Dragons Whatever It Takes
# -------------------------------
# add Imagine Dragons Machine
# -------------------------------
# add Imagine Dragons Demons
# -------------------------------
# add Imagine Dragons Zero - From the Original Motion Picture "Ralph Breaks The Internet"
# -------------------------------
# add Imagine Dragons Sucker For Pain (with Wiz Khalifa, Imagine Dragons, Logic & Ty Dolla $ign feat. X Ambassadors)
# -------------------------------
# ==============================
# add Little Mix Woman Like Me (feat. Nicki Minaj)
# -------------------------------
# add Little Mix Shout Out to My Ex
# -------------------------------
# add Little Mix Only You (with Little Mix)
# -------------------------------
# add Little Mix Black Magic
# -------------------------------
# add Little Mix Strip (feat. Sharaya J)
# -------------------------------
# add Little Mix Secret Love Song
# -------------------------------
# add Little Mix Joan of Arc
# -------------------------------
# add Little Mix Touch
# -------------------------------
# add Little Mix Wasabi
# -------------------------------
# add Little Mix Think About Us
# -------------------------------
# ==============================
# ==============================
# ==============================
# add Lil Peep Falling Down - Bonus Track
# -------------------------------
# add Lil Peep Save That Shit
# -------------------------------
# add Lil Peep Sex with My Ex
# -------------------------------
# add Lil Peep Life is Beautiful
# -------------------------------
# add Lil Peep Spotlight
# -------------------------------
# add Lil Peep Broken Smile (My All)
# -------------------------------
# add Lil Peep Runaway
# -------------------------------
# add Lil Peep Awful Things
# -------------------------------
# add Lil Peep Beamer Boy
# -------------------------------
# add Lil Peep Cry Alone
# -------------------------------
# ==============================
# add Kygo Happy Now (feat. Sandro Cavazza)
# -------------------------------
# add Kygo Born To Be Yours
# -------------------------------
# add Kygo Remind Me to Forget
# -------------------------------
# add Kygo It Ain't Me (with Selena Gomez)
# -------------------------------
# add Kygo Stargazing
# -------------------------------
# add Kygo Firestone (feat. Conrad Sewell)
# -------------------------------
# add Kygo First Time
# -------------------------------
# add Kygo Stole the Show
# -------------------------------
# add Kygo Stranger Things (feat. OneRepublic)
# -------------------------------
# add Kygo Sunrise (feat. Jason Walker)
# -------------------------------
# add Sandro Cavazza High With Somebody
# -------------------------------
# add Sandro Cavazza Used To
# -------------------------------
# add Sandro Cavazza So Much Better - Avicii Remix
# -------------------------------
# add Sandro Cavazza Don't Hold Me
# -------------------------------
# add Sandro Cavazza Don't Hold Me - Acoustic
# -------------------------------
# add Sandro Cavazza So Much Better - Lost Frequencies Remix
# -------------------------------
# add Sandro Cavazza What Kind Of Man
# -------------------------------
# add Sandro Cavazza So Much Better
# -------------------------------
# add Sandro Cavazza High With Somebody - Henri Purnell Remix
# -------------------------------
# add Sandro Cavazza Here
# -------------------------------
# ==============================
# add Manuel Turizo Desconocidos
# -------------------------------
# add Manuel Turizo Culpables
# -------------------------------
# add Manuel Turizo Una Lady Como Tú
# -------------------------------
# add Manuel Turizo Esperándote
# -------------------------------
# add Manuel Turizo Déjate Llevar
# -------------------------------
# add Manuel Turizo Sola
# -------------------------------
# add Manuel Turizo Una Vez Más
# -------------------------------
# add Manuel Turizo Una Lady Como Tú - Remix
# -------------------------------
# add Manuel Turizo Ser Un Cantante
# -------------------------------
# add Manuel Turizo Vámonos
# -------------------------------
# ==============================
# ==============================
# ==============================
# add Wham! Last Christmas - Remastered
# -------------------------------
# add Wham! Wake Me up Before You Go-Go
# -------------------------------
# add Wham! Everything She Wants
# -------------------------------
# add Wham! Club Tropicana
# -------------------------------
# add Wham! I'm Your Man
# -------------------------------
# add Wham! The Edge of Heaven
# -------------------------------
# add Wham! Freedom
# -------------------------------
# add Wham! Young Guns (Go for It!)
# -------------------------------
# add Wham! Last Christmas - Pudding Mix
# -------------------------------
# add Wham! Wham Rap! (Enjoy What You Do?)
# -------------------------------
# ==============================
# ==============================
# add David Guetta Goodbye (feat. Nicki Minaj & Willy William)
# -------------------------------
# add David Guetta Don't Leave Me Alone (feat. Anne-Marie)
# -------------------------------
# add David Guetta Say My Name
# -------------------------------
# add David Guetta Flames
# -------------------------------
# add David Guetta Like I Do
# -------------------------------
# add David Guetta Titanium (feat. Sia)
# -------------------------------
# add David Guetta Your Love
# -------------------------------
# add David Guetta So Far Away (feat. Jamie Scott & Romy Dya)
# -------------------------------
# add David Guetta Mad Love
# -------------------------------
# add David Guetta Drive (feat. Delilah Montagu) - Edit
# -------------------------------
# add Bebe Rexha I'm a Mess
# -------------------------------
# add Bebe Rexha Meant to Be (feat. Florida Georgia Line)
# -------------------------------
# add Bebe Rexha Say My Name
# -------------------------------
# add Bebe Rexha In the Name of Love
# -------------------------------
# add Bebe Rexha Me, Myself & I
# -------------------------------
# add Bebe Rexha Girls (feat. Cardi B, Bebe Rexha & Charli XCX)
# -------------------------------
# add Bebe Rexha Home (with Machine Gun Kelly, X Ambassadors & Bebe Rexha)
# -------------------------------
# add Bebe Rexha Bad Bitch (feat. Ty Dolla $ign)
# -------------------------------
# add Bebe Rexha I Got You
# -------------------------------
# add Bebe Rexha The Way I Are (Dance With Somebody) [feat. Lil Wayne]
# -------------------------------
# add J Balvin I Like It
# -------------------------------
# add J Balvin X - Remix
# -------------------------------
# add J Balvin No Es Justo
# -------------------------------
# add J Balvin Say My Name
# -------------------------------
# add J Balvin X
# -------------------------------
# add J Balvin Mocca - Remix
# -------------------------------
# add J Balvin Mi Cama - Remix
# -------------------------------
# add J Balvin Reggaeton
# -------------------------------
# add J Balvin Ponle
# -------------------------------
# add J Balvin Downtown
# -------------------------------
# ==============================
# add Ofenbach Paradise (feat. Benjamin Ingrosso)
# -------------------------------
# add Ofenbach Be Mine
# -------------------------------
# add Ofenbach Katchi (Ofenbach vs. Nick Waterhouse)
# -------------------------------
# add Ofenbach OK - Ofenbach Remix
# -------------------------------
# add Ofenbach Feel It Still - Ofenbach Remix
# -------------------------------
# add Ofenbach PARTY (feat. Wax and Herbal T) [Ofenbach vs. Lack Of Afro] - Ofenbach vs. Lack Of Afro
# -------------------------------
# add Ofenbach Come to Me - Ofenbach Remix
# -------------------------------
# add Ofenbach Solo (feat. Demi Lovato) - Ofenbach Remix
# -------------------------------
# add Ofenbach Be Mine - Acoustic Version
# -------------------------------
# add Ofenbach What I Want
# -------------------------------
# add Benjamin Ingrosso Behave
# -------------------------------
# add Benjamin Ingrosso Dance You Off
# -------------------------------
# add Benjamin Ingrosso Tror Du Att Han Bryr Sig
# -------------------------------
# add Benjamin Ingrosso I Wouldn't Know
# -------------------------------
# add Benjamin Ingrosso So Good so Fine When You're Messing with My Mind
# -------------------------------
# add Benjamin Ingrosso I'll Be Fine Somehow
# -------------------------------
# add Benjamin Ingrosso Spotlights
# -------------------------------
# add Benjamin Ingrosso Happiness
# -------------------------------
# add Benjamin Ingrosso One More Time
# -------------------------------
# add Benjamin Ingrosso Good Intentions
# -------------------------------
# ==============================
# add Kris Kross Amsterdam Whenever (feat. Conor Maynard)
# -------------------------------
# add Kris Kross Amsterdam Sex
# -------------------------------
# add Kris Kross Amsterdam Vámonos
# -------------------------------
# add Kris Kross Amsterdam Are You Sure? (feat. Ty Dolla $ign)
# -------------------------------
# add Kris Kross Amsterdam Whenever (feat. Conor Maynard) - Joe Stone Remix
# -------------------------------
# add Kris Kross Amsterdam Cheap Wine
# -------------------------------
# add Kris Kross Amsterdam Are You Sure? (feat. Ty Dolla $ign) - Eden Prince Remix
# -------------------------------
# add Kris Kross Amsterdam Gone Is The Night (feat. Jorge Blanco)
# -------------------------------
# add Kris Kross Amsterdam Are You Sure? (feat. Ty Dolla $ign) - Acoustic Version
# -------------------------------
# add Kris Kross Amsterdam Until The Morning - Joe Stone Remix Edit
# -------------------------------
# add The Boy Next Door Whenever (feat. Conor Maynard)
# -------------------------------
# add The Boy Next Door Whenever (feat. Conor Maynard) - Joe Stone Remix
# -------------------------------
# add The Boy Next Door La Colegiala
# -------------------------------
# add The Boy Next Door La Colegiala - Afro Bros Remix
# -------------------------------
# add The Boy Next Door Resistance (feat. $hirak)
# -------------------------------
# add Conor Maynard Whenever (feat. Conor Maynard)
# -------------------------------
# add Conor Maynard Don't Let Me Down
# -------------------------------
# add Conor Maynard All My Love (feat. Conor Maynard)
# -------------------------------
# add Conor Maynard That Way
# -------------------------------
# add Conor Maynard Hold On Tight
# -------------------------------
# add Conor Maynard This Is My Version
# -------------------------------
# add Conor Maynard Faded
# -------------------------------
# add Conor Maynard Cold Water
# -------------------------------
# add Conor Maynard Hold On Tight - Owen Norton Remix
# -------------------------------
# add Conor Maynard Despacito
# -------------------------------
# ==============================
# ==============================
# add Dadju Jaloux
# -------------------------------
# add Dadju Django
# -------------------------------
# add Dadju Bob Marley
# -------------------------------
# add Dadju Lionne
# -------------------------------
# add Dadju Par amour
# -------------------------------
# add Dadju Reine
# -------------------------------
# add Dadju Apollonia
# -------------------------------
# add Dadju Désaccord (en duo avec Dadju)
# -------------------------------
# add Dadju Sous contrôle
# -------------------------------
# add Dadju Sans thème - Remix
# -------------------------------
# ==============================
# ==============================
# add Jonas Blue Rise
# -------------------------------
# add Jonas Blue Polaroid
# -------------------------------
# add Jonas Blue Back & Forth
# -------------------------------
# add Jonas Blue Mama
# -------------------------------
# add Jonas Blue Fast Car
# -------------------------------
# add Jonas Blue Perfect Strangers
# -------------------------------
# add Jonas Blue Wherever You Go
# -------------------------------
# add Jonas Blue Rise - Acoustic
# -------------------------------
# add Jonas Blue I See Love
# -------------------------------
# add Jonas Blue By Your Side
# -------------------------------
# add Jack & Jack No One Compares To You
# -------------------------------
# add Jack & Jack Rise - Acoustic
# -------------------------------
# add Jack & Jack 2 Cigarettes
# -------------------------------
# add Jack & Jack Rise - Retrovision Remix
# -------------------------------
# add Jack & Jack Closure
# -------------------------------
# add Jack & Jack Beg
# -------------------------------
# add Jack & Jack Rise - TV Noise Ibiza Mix
# -------------------------------
# add Jack & Jack Hurt People
# -------------------------------
# add Jack & Jack Stay With Me
# -------------------------------
# add Jack & Jack I Don't Know
# -------------------------------
# ...
# -------------------------------
# add Antônio Carlos Jobim Para Machuchar Meu Coracao
# -------------------------------
# add Antônio Carlos Jobim Eu Sei Que Vou Te Amar
# -------------------------------
# add Antônio Carlos Jobim The Girl From Ipanema
# -------------------------------
# add Antônio Carlos Jobim O Morro Nao Tem Vez
# -------------------------------
# add Antônio Carlos Jobim Pela Luz dos Olhos Teus - Bonus Track
# -------------------------------
# add Antônio Carlos Jobim Triste
# -------------------------------
# add Antônio Carlos Jobim Fotografia
# -------------------------------
# add Newton Ferreira Mendonça One Note Samba
# -------------------------------
# add Newton Ferreira Mendonça Samba De Uma Nota Só (One Note Samba)
# -------------------------------
# add Newton Ferreira Mendonça Meditation
# -------------------------------
# add Newton Ferreira Mendonça Desafinado
# -------------------------------
# add Newton Ferreira Mendonça Meditation
# -------------------------------
# add Newton Ferreira Mendonça Meditacao
# -------------------------------
# add Newton Ferreira Mendonça One Note Samba / Spanish Flea
# -------------------------------
# add Newton Ferreira Mendonça Desafinado
# -------------------------------
# add Newton Ferreira Mendonça Samba De Uma Nota So (One Note Samba)
# -------------------------------
# add Newton Ferreira Mendonça One Note Samba (Samba De Uma Nota So)
# -------------------------------
# ==============================
# add Jennifer Lopez Te Guste
# -------------------------------
# add Jennifer Lopez El Anillo
# -------------------------------
# add Jennifer Lopez On The Floor - Radio Edit
# -------------------------------
# add Jennifer Lopez Ain't Your Mama
# -------------------------------
# add Jennifer Lopez Dinero
# -------------------------------
# add Jennifer Lopez Let's Get Loud
# -------------------------------
# add Jennifer Lopez El Anillo - Remix
# -------------------------------
# add Jennifer Lopez Jenny from the Block - Track Masters Remix
# -------------------------------
# add Jennifer Lopez Amor, Amor, Amor (feat. Wisin)
# -------------------------------
# add Jennifer Lopez Ni Tú Ni Yo (feat. Gente de Zona)
# -------------------------------
# add Marc Anthony Está Rico
# -------------------------------
# add Marc Anthony Vivir Mi Vida
# -------------------------------
# add Marc Anthony Flor Pálida
# -------------------------------
# add Marc Anthony Tu Amor Me Hace Bien - Salsa Version
# -------------------------------
# add Marc Anthony Adicto
# -------------------------------
# add Marc Anthony Qué Precio Tiene el Cielo - Salsa Version
# -------------------------------
# add Marc Anthony Valió la Pena - Salsa Version
# -------------------------------
# add Marc Anthony Y Cómo Es El
# -------------------------------
# add Marc Anthony Cambio de Piel
# -------------------------------
# add Marc Anthony Ahora Quien - Salsa Version
# -------------------------------
# ==============================
# add Craig David No Drama (feat. Craig David)
# -------------------------------
# add Craig David 7 Days
# -------------------------------
# add Craig David Heartline
# -------------------------------
# add Craig David I Know You
# -------------------------------
# add Craig David Come Alive - Bonus Track
# -------------------------------
# add Craig David GOT IT GOOD
# -------------------------------
# add Craig David Fill Me In
# -------------------------------
# add Craig David Walking Away
# -------------------------------
# add Craig David Nothing Like This
# -------------------------------
# add Craig David Intimate (feat. Craig David)
# -------------------------------
# ==============================
# add Sting Englishman In New York
# -------------------------------
# add Sting Shape Of My Heart
# -------------------------------
# add Sting Fields Of Gold
# -------------------------------
# add Sting Desert Rose
# -------------------------------
# add Sting Don't Make Me Wait (with Shaggy)
# -------------------------------
# add Sting Fragile
# -------------------------------
# add Sting It's Probably Me
# -------------------------------
# add Sting Morning Is Coming (with Shaggy)
# -------------------------------
# add Sting Englishman In New York - Reggae Version / Recorded At Spotfiy Studios NYC
# -------------------------------
# add Sting If I Ever Lose My Faith In You
# -------------------------------
# ==============================
# add Christophe Willem Double je - Remix
# -------------------------------
# add Christophe Willem Jacques a dit
# -------------------------------
# add Christophe Willem Après toi
# -------------------------------
# add Christophe Willem Marlon Brando
# -------------------------------
# add Christophe Willem Rio
# -------------------------------
# add Christophe Willem Je marche seul
# -------------------------------
# add Christophe Willem Double je
# -------------------------------
# add Christophe Willem Madame (Remix)
# -------------------------------
# add Christophe Willem Il y a
# -------------------------------
# add Christophe Willem Restart
# -------------------------------
# ==============================
# ==============================
# add Kungs This Girl (Kungs Vs. Cookin' On 3 Burners) - Kungs Vs. Cookin' On 3 Burners
# -------------------------------
# add Kungs Be Right Here
# -------------------------------
# add Kungs I Feel So Bad
# -------------------------------
# add Kungs Don't You Know - Radio Edit
# -------------------------------
# add Kungs Disco Night
# -------------------------------
# add Kungs This Girl (Kungs Vs Cookin' On 3 Burners) - Extended
# -------------------------------
# add Kungs More Mess
# -------------------------------
# add Kungs Tripping Off
# -------------------------------
# add Kungs Freedom
# -------------------------------
# add Kungs When You're Gone
# -------------------------------
# add Jamie N Commons Jungle - Remix
# -------------------------------
# add Jamie N Commons Lead Me Home - The Walking Dead Soundtrack
# -------------------------------
# add Jamie N Commons Rumble And Sway
# -------------------------------
# add Jamie N Commons Paper Dreams
# -------------------------------
# add Jamie N Commons Karma (Hardline)
# -------------------------------
# add Jamie N Commons Walls
# -------------------------------
# add Jamie N Commons Lead Me Home - Live At Spotify House
# -------------------------------
# add Jamie N Commons Jungle - The MADE Edit
# -------------------------------
# add Jamie N Commons Not Gonna Break Me
# -------------------------------
# add Jamie N Commons Glory
# -------------------------------
# ==============================
# add Daft Punk Get Lucky (feat. Pharrell Williams & Nile Rodgers) - Radio Edit
# -------------------------------
# add Daft Punk One More Time
# -------------------------------
# add Daft Punk Instant Crush
# -------------------------------
# add Daft Punk Lose Yourself to Dance
# -------------------------------
# add Daft Punk Get Lucky
# -------------------------------
# add Daft Punk Harder Better Faster Stronger
# -------------------------------
# add Daft Punk Something About Us
# -------------------------------
# add Daft Punk Around The World
# -------------------------------
# add Daft Punk One More Time - Short Radio Edit
# -------------------------------
# add Daft Punk Doin' it Right
# -------------------------------
# add Todd Edwards All Falls Down (feat. Juliander) - Todd Edwards Remix
# -------------------------------
# add Todd Edwards Pure Pleasure Seeker - Todd Edwards Pure Pleasure Disco Vocal
# -------------------------------
# add Todd Edwards Techno Disco Tool - Todd Edwards Remix
# -------------------------------
# add Todd Edwards Pure Pleasure Seeker - Todd Edwards Pleasure for Life Mix
# -------------------------------
# add Todd Edwards Catch My Breath - Radio Edit
# -------------------------------
# add Todd Edwards We Could Go Back - Todd Edwards Remix
# -------------------------------
# add Todd Edwards Lay Me Down - Todd Edwards Dub
# -------------------------------
# add Todd Edwards Shades Of Grey - Todd Edwards Remix
# -------------------------------
# add Todd Edwards Hold The Faith
# -------------------------------
# add Todd Edwards Sing It Back - Todd Edwards Remix / Radio Edit
# -------------------------------
# ==============================
# add R I T U A L Drown The Lovers
# -------------------------------
# add R I T U A L The Only One
# -------------------------------
# add R I T U A L Bottle Tops
# -------------------------------
# add R I T U A L Better By Now
# -------------------------------
# add R I T U A L Wouldn't Be Love
# -------------------------------
# add R I T U A L Hotel Bars
# -------------------------------
# add R I T U A L Amen
# -------------------------------
# add R I T U A L Drown The Lovers
# -------------------------------
# add R I T U A L Wouldn't Be Love - Acoustic
# -------------------------------
# add R I T U A L Real Feels
# -------------------------------
# ==============================
# add Mary J. Blige Family Affair
# -------------------------------
# add Mary J. Blige Be Without You - Kendu Mix
# -------------------------------
# add Mary J. Blige As
# -------------------------------
# add Mary J. Blige Real Love
# -------------------------------
# add Mary J. Blige Do You Hear What I Hear?
# -------------------------------
# add Mary J. Blige Only Love
# -------------------------------
# add Mary J. Blige Reminisce
# -------------------------------
# add Mary J. Blige Sweet Thing
# -------------------------------
# add Mary J. Blige Just Fine
# -------------------------------
# add Mary J. Blige I Can Love You
# -------------------------------
# add George Michael Careless Whisper
# -------------------------------
# add George Michael Faith - Remastered
# -------------------------------
# add George Michael Freedom! '90 - Remastered
# -------------------------------
# add George Michael Father Figure - Remastered
# -------------------------------
# add George Michael Fastlove, Pt. 1
# -------------------------------
# add George Michael I Knew You Were Waiting (For Me)
# -------------------------------
# add George Michael Don't Let the Sun Go Down on Me
# -------------------------------
# add George Michael As
# -------------------------------
# add George Michael Jesus to a Child
# -------------------------------
# add George Michael Don't Let the Sun Go Down on Me
# -------------------------------
# ==============================
# add Simply Red If You Don't Know Me By Now - 2008 Remastered Version
# -------------------------------
# add Simply Red Stars
# -------------------------------
# add Simply Red Holding Back the Years - 2008 Remastered Version
# -------------------------------
# add Simply Red For Your Babies
# -------------------------------
# add Simply Red Something Got Me Started
# -------------------------------
# add Simply Red Sunrise
# -------------------------------
# add Simply Red The Air That I Breathe
# -------------------------------
# add Simply Red You Make Me Feel Brand New - Live at Sydney Opera House
# -------------------------------
# add Simply Red Money's Too Tight - 2008 Remastered Version
# -------------------------------
# add Simply Red It's Only Love - 2008 Remastered Version
# -------------------------------
# ==============================
# add George Benson Nothing's Gonna Change My Love For You
# -------------------------------
# add George Benson Give Me The Night - Edit
# -------------------------------
# add George Benson Breezin' - Remastered
# -------------------------------
# add George Benson Give Me the Night
# -------------------------------
# add George Benson On Broadway - Edit
# -------------------------------
# add George Benson Turn Your Love Around
# -------------------------------
# add George Benson Since I Fell For You
# -------------------------------
# add George Benson In Your Eyes
# -------------------------------
# add George Benson This Masquerade
# -------------------------------
# add George Benson Love X Love
# -------------------------------
# ==============================
# ==============================
# ==============================
# add Seal Kiss From A Rose
# -------------------------------
# add Seal Crazy
# -------------------------------
# add Seal Kiss From A Rose - Acoustic Version
# -------------------------------
# add Seal My Funny Valentine
# -------------------------------
# add Seal Stand By Me
# -------------------------------
# add Seal Fly Like An Eagle
# -------------------------------
# add Seal Santa Claus Is Coming To Town
# -------------------------------
# add Seal Love's Divine
# -------------------------------
# add Seal Crazy
# -------------------------------
# add Seal Luck Be A Lady
# -------------------------------
# add Karlin Brokenhearted - Soulpower Mix
# -------------------------------
# add Karlin Walk On By - Master S&K Mix
# -------------------------------
# add Karlin Casualties Of War - Soulpower Remix
# -------------------------------
# add Karlin Bridge Over Troubled Water (Cover) - Radio Edition
# -------------------------------
# add Karlin Kribbeln im Bauch
# -------------------------------
# add Karlin Wunderkind
# -------------------------------
# add Karlin Sin Ti
# -------------------------------
# add Soulshock Walk On By - Master S&K Mix
# -------------------------------
# add Soulshock (I Wanna Make) Love To You - Cutfather & Soulshock Remix
# -------------------------------
# ==============================
# add Irma Hear Me Out
# -------------------------------
# add Irma I Know
# -------------------------------
# add Irma Streets of Philadelphia - Les stars font leur cinéma
# -------------------------------
# add Irma Let's Talk About Love
# -------------------------------
# add Irma Save Me
# -------------------------------
# add Irma Street Light
# -------------------------------
# add Irma Letter to the Lord
# -------------------------------
# add Irma Catch the Wind
# -------------------------------
# add Irma Everybody
# -------------------------------
# add Irma Your Guide
# -------------------------------
# ==============================
# add Chris Rea Driving Home For Christmas
# -------------------------------
# add Chris Rea The Road to Hell, Pt. 1 & 2 - New Version 2008
# -------------------------------
# add Chris Rea The Road to Hell, Pt. 2
# -------------------------------
# add Chris Rea Josephine - New Version 2008
# -------------------------------
# add Chris Rea On the Beach - New Version 2008
# -------------------------------
# add Chris Rea Josephine
# -------------------------------
# add Chris Rea Looking For The Summer
# -------------------------------
# add Chris Rea Josephine - Symphonic Version
# -------------------------------
# add Chris Rea On The Beach
# -------------------------------
# add Chris Rea Fool (If You Think It's Over) - New Version 2008
# -------------------------------
# ==============================
# add Michael Jackson Don’t Matter To Me (with Michael Jackson)
# -------------------------------
# add Michael Jackson Billie Jean
# -------------------------------
# add Michael Jackson Beat It - Single Version
# -------------------------------
# add Michael Jackson Smooth Criminal - 2012 Remaster
# -------------------------------
# add Michael Jackson Don't Stop 'Til You Get Enough - Single Version
# -------------------------------
# add Michael Jackson Rock with You - Single Version
# -------------------------------
# add Michael Jackson Love Never Felt so Good
# -------------------------------
# add Michael Jackson Remember the Time
# -------------------------------
# add Michael Jackson Thriller
# -------------------------------
# add Michael Jackson P.Y.T. (Pretty Young Thing)
# -------------------------------
# ==============================
# ==============================
# ==============================
# ==============================
# add Esther Phillips And I Love Him
# -------------------------------
# add Esther Phillips Use Me
# -------------------------------
# add Esther Phillips The Storm (01-16-52)
# -------------------------------
# add Esther Phillips Home Is Where the Hatred Is
# -------------------------------
# add Esther Phillips No Headstone On My Grave
# -------------------------------
# add Esther Phillips Alone Again (Naturally)
# -------------------------------
# add Esther Phillips I Feel the Same
# -------------------------------
# add Esther Phillips Just Say Goodbye
# -------------------------------
# add Esther Phillips That's All Right with Me
# -------------------------------
# add Esther Phillips Girl From Ipanema
# -------------------------------

# %%
df.head(10)
# Out:
#    acousticness               artist_id    artist_name  artist_popuplarity  \
# 0        0.2800  66CXWjxzNUsdJxJ2JdwvnR  Ariana Grande                97.0
# 1        0.0211  66CXWjxzNUsdJxJ2JdwvnR  Ariana Grande                97.0
# 2        0.0233  66CXWjxzNUsdJxJ2JdwvnR  Ariana Grande                97.0
# 3        0.0400  66CXWjxzNUsdJxJ2JdwvnR  Ariana Grande                97.0
# 4        0.0545  66CXWjxzNUsdJxJ2JdwvnR  Ariana Grande                97.0
# 5        0.0513  66CXWjxzNUsdJxJ2JdwvnR  Ariana Grande                97.0
# 6        0.0162  66CXWjxzNUsdJxJ2JdwvnR  Ariana Grande                97.0
# 7        0.0914  66CXWjxzNUsdJxJ2JdwvnR  Ariana Grande                97.0
# 8        0.2480  66CXWjxzNUsdJxJ2JdwvnR  Ariana Grande                97.0
# 9        0.1860  66CXWjxzNUsdJxJ2JdwvnR  Ariana Grande                97.0
#
#    danceability  duration_ms  energy  instrumentalness   key  liveness  \
# 0         0.724      106.960   0.647          0.000000   1.0    0.1020
# 1         0.568      100.049   0.656          0.000014   8.0    0.2130
# 2         0.602      145.031   0.658          0.000060   1.0    0.2370
# 3         0.699      121.993   0.713          0.000003   9.0    0.2940
# 4         0.506      191.708   0.628          0.000000   7.0    0.3010
# 5         0.650      159.174   0.736          0.000000   6.0    0.2350
# 6         0.623      107.853   0.734          0.000002   9.0    0.1450
# 7         0.626      125.001   0.604          0.000001   8.0    0.1030
# 8         0.721      119.914   0.459          0.000000   4.0    0.2120
# 9         0.710      148.152   0.614          0.000000  10.0    0.0974
#
#    loudness  mode                 song_id             song_name  \
# 0    -5.642   1.0  2rPE9A1vEgShuZxxzR2tZH         thank u, next
# 1    -5.413   1.0  4OafepJy2teCjYJbvFE60J              breathin
# 2    -5.934   1.0  5OCJzvD7sykQEKHH7qAC3C        God is a woman
# 3    -5.507   0.0  2qT1uLXPVPzGgFOx4jtEuo  no tears left to cry
# 4    -7.316   1.0  0lizgQ7Qw35od7CYaoMBZb         Santa Tell Me
# 5    -5.840   0.0  1pKeFVVUOPjFsOABub0OaV          Side To Side
# 6    -5.950   1.0  2meEiZKWkiN28gITzFwQo5              Into You
# 7    -4.998   1.0  50rGbTr2wrWnlIelPQxi87         One Last Time
# 8    -6.408   1.0  70khXICDeTTxgYtw3EysKH             sweetener
# 9    -6.757   0.0  0WdR2AyLW1Drd3OUdwezM0             everytime
#
#    song_popuplarity  speechiness    tempo  time_signature  valence
# 0             100.0       0.0658  106.960             4.0    0.435
# 1              90.0       0.0433  100.049             4.0    0.364
# 2              89.0       0.0558  145.031             4.0    0.268
# 3              89.0       0.0594  121.993             4.0    0.354
# 4              84.0       0.1730  191.708             4.0    0.556
# 5              82.0       0.2290  159.174             4.0    0.612
# 6              81.0       0.1070  107.853             4.0    0.372
# 7              52.0       0.0329  125.001             4.0    0.127
# 8              81.0       0.0320  119.914             4.0    0.460
# 9              79.0       0.0431  148.152             4.0    0.658

# %%
df.shape
# Out:
# (1718, 19)

# %% [markdown]
# ## Exploration des données

# %%
df.describe()
# Out:
#        acousticness  artist_popuplarity  danceability  duration_ms  \
# count   1718.000000         1718.000000   1718.000000  1718.000000
# mean       0.349684           75.176950      0.631464   117.390780
# std        0.333646           15.908998      0.169062    27.977764
# min        0.000019           17.000000      0.085400    35.995000
# 25%        0.057525           67.000000      0.533250    97.043250
# 50%        0.224000           78.000000      0.661000   117.954500
# 75%        0.595000           87.000000      0.753000   133.995250
# max        0.996000          100.000000      0.981000   207.431000
#
#             energy  instrumentalness          key     liveness     loudness  \
# count  1718.000000       1718.000000  1718.000000  1718.000000  1718.000000
# mean      0.572409          0.087213     5.255530     0.166558    -8.670572
# std       0.243311          0.250502     3.584964     0.131877     6.412492
# min       0.002500          0.000000     0.000000     0.021500   -40.563000
# 25%       0.435000          0.000000     2.000000     0.092625    -9.309000
# 50%       0.631000          0.000002     5.000000     0.116000    -6.601000
# 75%       0.752000          0.000682     8.000000     0.190750    -5.034000
# max       0.989000          0.969000    11.000000     0.982000     0.175000
#
#               mode  song_popuplarity  speechiness        tempo  \
# count  1718.000000       1718.000000  1718.000000  1718.000000
# mean      0.543655         60.058789     0.091101   117.390780
# std       0.498236         19.205765     0.088586    27.977764
# min       0.000000          0.000000     0.023200    35.995000
# 25%       0.000000         49.000000     0.038800    97.043250
# 50%       1.000000         62.000000     0.054050   117.954500
# 75%       1.000000         75.000000     0.102750   133.995250
# max       1.000000        100.000000     0.737000   207.431000
#
#        time_signature      valence
# count     1718.000000  1718.000000
# mean         3.939464     0.476389
# std          0.376744     0.239319
# min          1.000000     0.033800
# 25%          4.000000     0.290000
# 50%          4.000000     0.470000
# 75%          4.000000     0.651750
# max          5.000000     0.972000

# %%
corr = df.corr()
plt.figure(figsize = (9,7))
sns.heatmap(corr)

# %%
df.sort_values(by=['song_popuplarity'],ascending=False)[['song_name','artist_name','song_popuplarity']].head(20)
# Out:
#                                           song_name    artist_name  \
# 0                                     thank u, next  Ariana Grande
# 20   Taki Taki (with Selena Gomez, Ozuna & Cardi B)   Selena Gomez
# 30   Taki Taki (with Selena Gomez, Ozuna & Cardi B)          Ozuna
# 10   Taki Taki (with Selena Gomez, Ozuna & Cardi B)       DJ Snake
# 50                                MIA (feat. Drake)      Bad Bunny
# 130                                         Happier     Marshmello
# 140                                         Happier       Bastille
# 100                                      Without Me         Halsey
# 190   Sunflower - Spider-Man: Into the Spider-Verse       Swae Lee
# 180   Sunflower - Spider-Man: Into the Spider-Verse    Post Malone
# 150                                      SICKO MODE   Travis Scott
# 160              ZEZE (feat. Travis Scott & Offset)    Kodak Black
# 101                 Eastside (with Halsey & Khalid)         Halsey
# 230       Arms Around You (feat. Maluma & Swae Lee)       Lil Pump
# 330                 Eastside (with Halsey & Khalid)         Khalid
# 220       Arms Around You (feat. Maluma & Swae Lee)   XXXTENTACION
# 191       Arms Around You (feat. Maluma & Swae Lee)       Swae Lee
# 350                 Eastside (with Halsey & Khalid)   benny blanco
# 260                                        Mo Bamba      Sheck Wes
# 221                                            SAD!   XXXTENTACION
#
#      song_popuplarity
# 0               100.0
# 20               99.0
# 30               99.0
# 10               99.0
# 50               97.0
# 130              97.0
# 140              97.0
# 100              96.0
# 190              95.0
# 180              95.0
# 150              95.0
# 160              95.0
# 101              94.0
# 230              94.0
# 330              94.0
# 220              94.0
# 191              94.0
# 350              94.0
# 260              93.0
# 221              93.0

# %%
df_copy = df.copy()
threshold = df_copy.song_popuplarity.mean()
df['isPopular'] = 0
df_copy = df_copy.set_value(df[df.song_popuplarity>threshold].index,'isPopular',1)
df_copy.sort_values(by='song_popuplarity', ascending=False).head(10)
# Out:
# C:\Users\sebas\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   after removing the cwd from sys.path.
#      acousticness               artist_id    artist_name  artist_popuplarity  \
# 0          0.2800  66CXWjxzNUsdJxJ2JdwvnR  Ariana Grande                97.0
# 20         0.1530  0C8ZW7ezQVs4URX5aX7Kqx   Selena Gomez                91.0
# 30         0.1530  1i8SpTcr7yvPOmcqrbnVXY          Ozuna                97.0
# 10         0.1530  540vIaP2JwjQb9dm3aArA4       DJ Snake                89.0
# 50         0.0141  4q3ewBCX7sLwd24euuV69X      Bad Bunny                95.0
# 130        0.1910  64KEffDW9EtZ1y2vBYgq8T     Marshmello                90.0
# 140        0.1910  7EQ0qTo7fWT7DPxmxtSYEc       Bastille                87.0
# 100        0.2970  26VFTg2z8YR0cCuwLzESi2         Halsey                91.0
# 190        0.5510  1zNqQNIdeOUZHb8zbZRFMX       Swae Lee                92.0
# 180        0.5510  246dkjvS1zLTtiykXe5h60    Post Malone                96.0
#
#      danceability  duration_ms  energy  instrumentalness  key  liveness  \
# 0           0.724      106.960   0.647          0.000000  1.0    0.1020
# 20          0.841       95.948   0.798          0.000003  1.0    0.0618
# 30          0.841       95.948   0.798          0.000003  1.0    0.0618
# 10          0.841       95.948   0.798          0.000003  1.0    0.0618
# 50          0.817       97.062   0.539          0.000496  6.0    0.0990
# 130         0.687      100.015   0.792          0.000000  5.0    0.1670
# 140         0.687      100.015   0.792          0.000000  5.0    0.1670
# 100         0.752      136.041   0.488          0.000009  6.0    0.0936
# 190         0.753       89.950   0.498          0.000000  2.0    0.0706
# 180         0.753       89.950   0.498          0.000000  2.0    0.0706
#
#      loudness  mode                 song_id  \
# 0      -5.642   1.0  2rPE9A1vEgShuZxxzR2tZH
# 20     -4.206   0.0  4w8niZpiMy6qz1mntFA5uM
# 30     -4.206   0.0  4w8niZpiMy6qz1mntFA5uM
# 10     -4.206   0.0  4w8niZpiMy6qz1mntFA5uM
# 50     -6.349   0.0  116H0KvKr2Zl4RPuVBruDO
# 130    -2.749   1.0  2dpaYNEQHiRxtZbfNsse99
# 140    -2.749   1.0  2dpaYNEQHiRxtZbfNsse99
# 100    -7.050   1.0  5p7ujcrUXASCNwRaWNHR1C
# 190    -5.610   1.0  1A6OTy97kk0mMdm78rHsm8
# 180    -5.610   1.0  1A6OTy97kk0mMdm78rHsm8
#
#                                           song_name  song_popuplarity  \
# 0                                     thank u, next             100.0
# 20   Taki Taki (with Selena Gomez, Ozuna & Cardi B)              99.0
# 30   Taki Taki (with Selena Gomez, Ozuna & Cardi B)              99.0
# 10   Taki Taki (with Selena Gomez, Ozuna & Cardi B)              99.0
# 50                                MIA (feat. Drake)              97.0
# 130                                         Happier              97.0
# 140                                         Happier              97.0
# 100                                      Without Me              96.0
# 190   Sunflower - Spider-Man: Into the Spider-Verse              95.0
# 180   Sunflower - Spider-Man: Into the Spider-Verse              95.0
#
#      speechiness    tempo  time_signature  valence  isPopular
# 0         0.0658  106.960             4.0    0.435        1.0
# 20        0.2290   95.948             4.0    0.591        1.0
# 30        0.2290   95.948             4.0    0.591        1.0
# 10        0.2290   95.948             4.0    0.591        1.0
# 50        0.0621   97.062             4.0    0.158        1.0
# 130       0.0452  100.015             4.0    0.671        1.0
# 140       0.0452  100.015             4.0    0.671        1.0
# 100       0.0705  136.041             4.0    0.533        1.0
# 190       0.0504   89.950             4.0    0.927        1.0
# 180       0.0504   89.950             4.0    0.927        1.0

# %% [markdown]
# ## Importance des features

# %%
from sklearn.ensemble import RandomForestRegressor
X = df.drop(['song_popuplarity','isPopular'],axis=1)
X = X.select_dtypes(exclude=[object])
Y = df['song_popuplarity'].values

model = RandomForestRegressor(n_estimators=10,max_depth=40)
model.fit(X,Y)
# Out:
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=40,
#            max_features='auto', max_leaf_nodes=None,
#            min_impurity_decrease=0.0, min_impurity_split=None,
#            min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=None,
#            oob_score=False, random_state=None, verbose=0, warm_start=False)

# %%
features = X.columns
feature_importances = model.feature_importances_
features_df = pd.DataFrame({'Features': features, 'Importance Score': feature_importances})
features_df.sort_values('Importance Score', inplace=True, ascending=False)
features_df.plot(x='Features',y='Importance Score',kind='barh', figsize=(12,10))
plt.show()

# %%
# Drop Artist Populariy :
X_copy = X.copy()
X_copy = X_copy.drop('artist_popuplarity',axis=1)

# %%
from sklearn.model_selection import train_test_split
from sklearn import datasets, linear_model

X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.3, random_state = 2)

# %%
from sklearn.ensemble import RandomForestRegressor

model = RandomForestRegressor(n_estimators=10,max_depth=40)
model.fit(X_train,Y_train)
model.score(X_train,Y_train)
# Out:
# 0.9464990641299007

# %%
model.score(X_test,Y_test)
# Out:
# 0.7285877908236078

# %%
X_copy = X.copy()
X_copy = X_copy.drop('artist_popuplarity',axis=1)

# %%
model = RandomForestRegressor(n_estimators=10,max_depth=40)
model.fit(X_copy,Y)
model.score(X_copy,Y)
# Out:
# 0.8677224979489065

# %%
features = X_copy.columns
feature_importances = model.feature_importances_
features_df = pd.DataFrame({'Features': features, 'Importance Score': feature_importances})
features_df.sort_values('Importance Score', inplace=True, ascending=False)
features_df.plot(x='Features',y='Importance Score',kind='barh', figsize=(12,10))
plt.show()

# %%
X
# Out:
#       acousticness  artist_popuplarity  danceability  duration_ms  energy  \
# 0         0.280000                97.0         0.724      106.960   0.647
# 1         0.021100                97.0         0.568      100.049   0.656
# 2         0.023300                97.0         0.602      145.031   0.658
# 3         0.040000                97.0         0.699      121.993   0.713
# 4         0.054500                97.0         0.506      191.708   0.628
# 5         0.051300                97.0         0.650      159.174   0.736
# 6         0.016200                97.0         0.623      107.853   0.734
# 7         0.091400                97.0         0.626      125.001   0.604
# 8         0.248000                97.0         0.721      119.914   0.459
# 9         0.186000                97.0         0.710      148.152   0.614
# 10        0.153000                89.0         0.841       95.948   0.798
# 11        0.077100                89.0         0.652      100.023   0.713
# 12        0.347000                89.0         0.449      134.598   0.597
# 13        0.020300                89.0         0.586      104.957   0.701
# 14        0.495000                89.0         0.784      104.996   0.757
# 15        0.000410                89.0         0.604      102.053   0.897
# 16        0.003460                89.0         0.723       98.007   0.809
# 17        0.001070                89.0         0.818      100.014   0.799
# 18        0.011300                89.0         0.426      196.133   0.722
# 19        0.009000                89.0         0.704      127.992   0.989
# 20        0.153000                91.0         0.841       95.948   0.798
# 21        0.094500                91.0         0.601      102.061   0.724
# 22        0.129000                91.0         0.720      124.946   0.807
# 23        0.119000                91.0         0.640       99.968   0.533
# 24        0.189000                91.0         0.965      121.032   0.414
# 25        0.019800                91.0         0.707      123.006   0.611
# 26        0.053000                91.0         0.616       83.066   0.789
# 27        0.007950                91.0         0.757      120.012   0.884
# 28        0.014700                91.0         0.811      111.016   0.499
# 29        0.022300                91.0         0.672       98.020   0.593
# ...            ...                 ...           ...          ...     ...
# 1688      0.328000                68.0         0.497      180.225   0.661
# 1689      0.010000                68.0         0.562      133.982   0.689
# 1690      0.000449                68.0         0.634      134.994   0.623
# 1691      0.013400                68.0         0.657      107.975   0.706
# 1692      0.385000                68.0         0.704      104.986   0.468
# 1693      0.022300                68.0         0.656      110.037   0.469
# 1694      0.080800                68.0         0.565       95.027   0.670
# 1695      0.023200                68.0         0.477       95.708   0.656
# 1696      0.229000                68.0         0.735      127.970   0.728
# 1697      0.320000                68.0         0.731       95.962   0.560
# 1698      0.493000                86.0         0.826      103.002   0.318
# 1699      0.023600                86.0         0.920      117.046   0.654
# 1700      0.049100                86.0         0.779      138.858   0.867
# 1701      0.247000                86.0         0.853      118.193   0.981
# 1702      0.126000                86.0         0.878      118.881   0.821
# 1703      0.179000                86.0         0.808      114.031   0.535
# 1704      0.132000                86.0         0.775      117.513   0.719
# 1705      0.153000                86.0         0.831      108.002   0.921
# 1706      0.085500                86.0         0.773      118.458   0.859
# 1707      0.230000                86.0         0.888      127.273   0.815
# 1708      0.309000                44.0         0.594      106.370   0.276
# 1709      0.630000                44.0         0.676      164.509   0.428
# 1710      0.948000                44.0         0.542       66.012   0.467
# 1711      0.160000                44.0         0.484       99.346   0.603
# 1712      0.647000                44.0         0.552       94.852   0.365
# 1713      0.774000                44.0         0.556       94.761   0.636
# 1714      0.121000                44.0         0.665       77.783   0.504
# 1715      0.752000                44.0         0.717      109.354   0.465
# 1716      0.571000                44.0         0.447       91.824   0.322
# 1717      0.559000                44.0         0.406       88.822   0.295
#
#       instrumentalness   key  liveness  loudness  mode  speechiness    tempo  \
# 0             0.000000   1.0    0.1020    -5.642   1.0       0.0658  106.960
# 1             0.000014   8.0    0.2130    -5.413   1.0       0.0433  100.049
# 2             0.000060   1.0    0.2370    -5.934   1.0       0.0558  145.031
# 3             0.000003   9.0    0.2940    -5.507   0.0       0.0594  121.993
# 4             0.000000   7.0    0.3010    -7.316   1.0       0.1730  191.708
# 5             0.000000   6.0    0.2350    -5.840   0.0       0.2290  159.174
# 6             0.000002   9.0    0.1450    -5.950   1.0       0.1070  107.853
# 7             0.000001   8.0    0.1030    -4.998   1.0       0.0329  125.001
# 8             0.000000   4.0    0.2120    -6.408   1.0       0.0320  119.914
# 9             0.000000  10.0    0.0974    -6.757   0.0       0.0431  148.152
# 10            0.000003   1.0    0.0618    -4.206   0.0       0.2290   95.948
# 11            0.000010   8.0    0.1440    -5.311   1.0       0.0368  100.023
# 12            0.000010   9.0    0.1970    -4.401   0.0       0.1400  134.598
# 13            0.000000   1.0    0.0550    -5.326   0.0       0.0416  104.957
# 14            0.000001   8.0    0.1420    -3.912   1.0       0.0384  104.996
# 15            0.838000  10.0    0.3270    -3.678   0.0       0.0641  102.053
# 16            0.001230   7.0    0.5650    -3.081   0.0       0.0625   98.007
# 17            0.128000   1.0    0.0570    -4.100   0.0       0.1560  100.014
# 18            0.000001   5.0    0.2620    -5.369   0.0       0.1960  196.133
# 19            0.044300   8.0    0.0814    -5.079   1.0       0.0730  127.992
# 20            0.000003   1.0    0.0618    -4.206   0.0       0.2290   95.948
# 21            0.000002   6.0    0.1200    -4.856   1.0       0.0486  102.061
# 22            0.000000  11.0    0.1830    -4.590   0.0       0.0432  124.946
# 23            0.000000   0.0    0.0864    -6.596   1.0       0.0706   99.968
# 24            0.000000   1.0    0.0767    -6.408   1.0       0.0713  121.032
# 25            0.000004   2.0    0.0651    -4.474   1.0       0.0639  123.006
# 26            0.000000   7.0    0.1420    -4.874   0.0       0.0377   83.066
# 27            0.000059  10.0    0.0973    -5.488   0.0       0.0404  120.012
# 28            0.000002   5.0    0.3420    -7.161   0.0       0.1180  111.016
# 29            0.000000  11.0    0.2140    -4.010   0.0       0.0304   98.020
# ...                ...   ...       ...       ...   ...          ...      ...
# 1688          0.000317   9.0    0.2110    -9.047   1.0       0.0361  180.225
# 1689          0.023000   9.0    0.0481    -9.717   0.0       0.0361  133.982
# 1690          0.010800   9.0    0.0649    -8.855   0.0       0.0258  134.994
# 1691          0.000198   7.0    0.5690   -10.187   1.0       0.0232  107.975
# 1692          0.000110   4.0    0.1090   -12.136   0.0       0.0249  104.986
# 1693          0.008660   3.0    0.0475   -15.941   0.0       0.0281  110.037
# 1694          0.466000  11.0    0.0518   -13.777   0.0       0.0320   95.027
# 1695          0.047100   2.0    0.2690    -8.950   0.0       0.0298   95.708
# 1696          0.000027   5.0    0.0657    -7.405   0.0       0.0405  127.970
# 1697          0.024400  11.0    0.2700   -10.015   0.0       0.0247   95.962
# 1698          0.013100  10.0    0.1100   -12.391   1.0       0.0574  103.002
# 1699          0.015800  11.0    0.0359    -3.051   0.0       0.0401  117.046
# 1700          0.000008   3.0    0.1970    -3.704   0.0       0.0457  138.858
# 1701          0.468000   8.0    0.3060    -3.947   1.0       0.0751  118.193
# 1702          0.046100  11.0    0.1830    -9.875   1.0       0.0890  118.881
# 1703          0.000099   1.0    0.1580   -12.521   1.0       0.0353  114.031
# 1704          0.000002   7.0    0.0662    -6.212   0.0       0.0435  117.513
# 1705          0.002130   5.0    0.3050    -2.383   0.0       0.0581  108.002
# 1706          0.000180  11.0    0.9140    -4.913   1.0       0.0747  118.458
# 1707          0.000424  11.0    0.1270    -4.909   0.0       0.0404  127.273
# 1708          0.000000   3.0    0.0829   -10.726   0.0       0.0262  106.370
# 1709          0.000039   8.0    0.0645    -9.600   1.0       0.0789  164.509
# 1710          0.000596   3.0    0.1900    -7.453   0.0       0.0478   66.012
# 1711          0.008750  11.0    0.1230   -10.420   0.0       0.0652   99.346
# 1712          0.021100  10.0    0.2460    -8.907   1.0       0.0376   94.852
# 1713          0.004720   8.0    0.1110    -8.451   1.0       0.0688   94.761
# 1714          0.000012  10.0    0.1010    -8.626   0.0       0.0401   77.783
# 1715          0.000051   2.0    0.5570   -12.027   0.0       0.0554  109.354
# 1716          0.000060   1.0    0.0792    -9.490   1.0       0.0317   91.824
# 1717          0.000000   8.0    0.2750   -13.836   1.0       0.0384   88.822
#
#       time_signature  valence
# 0                4.0   0.4350
# 1                4.0   0.3640
# 2                4.0   0.2680
# 3                4.0   0.3540
# 4                4.0   0.5560
# 5                4.0   0.6120
# 6                4.0   0.3720
# 7                4.0   0.1270
# 8                4.0   0.4600
# 9                4.0   0.6580
# 10               4.0   0.5910
# 11               4.0   0.1520
# 12               5.0   0.5050
# 13               4.0   0.2540
# 14               4.0   0.5870
# 15               4.0   0.5880
# 16               4.0   0.2740
# 17               4.0   0.0815
# 18               4.0   0.2500
# 19               4.0   0.1230
# 20               4.0   0.5910
# 21               4.0   0.5080
# 22               4.0   0.3050
# 23               4.0   0.5150
# 24               4.0   0.7280
# 25               4.0   0.2850
# 26               4.0   0.6210
# 27               4.0   0.3980
# 28               4.0   0.4660
# 29               4.0   0.4380
# ...              ...      ...
# 1688             4.0   0.8940
# 1689             4.0   0.4620
# 1690             4.0   0.8670
# 1691             4.0   0.7700
# 1692             4.0   0.4750
# 1693             4.0   0.6600
# 1694             4.0   0.2530
# 1695             4.0   0.5230
# 1696             4.0   0.9600
# 1697             4.0   0.8710
# 1698             4.0   0.1380
# 1699             4.0   0.8470
# 1700             4.0   0.9150
# 1701             4.0   0.5950
# 1702             4.0   0.9470
# 1703             4.0   0.8480
# 1704             4.0   0.7120
# 1705             4.0   0.7940
# 1706             4.0   0.8130
# 1707             4.0   0.9610
# 1708             4.0   0.6020
# 1709             4.0   0.8200
# 1710             3.0   0.2930
# 1711             4.0   0.8460
# 1712             3.0   0.5380
# 1713             4.0   0.6130
# 1714             4.0   0.5760
# 1715             4.0   0.8240
# 1716             3.0   0.3420
# 1717             3.0   0.7680
#
# [1718 rows x 14 columns]

# %%
# from pandas.plotting import radviz
# plt.figure(figsize=(12,12))
# radviz(df_copy.loc[:,df_copy.columns],class_column=('isPopular'))

# %%
import pandas as pd
import spotipy
import spotify_token
import seaborn as sns
import matplotlib.pyplot as plt

column = ['artist', 'track', 'type', 'publish_date', 'rank']
df = pd.read_csv("~/Downloads/data_BB.csv", names=column, header=None)
df = df.iloc[1:]

occurence_artiste = df['artist'].value_counts()
liste_artiste= list(occurence_artiste.index)
meilleur_artiste = pd.DataFrame({"artiste":liste_artiste,
                               "occurence_artiste":occurence_artiste})
dix_meilleurs = meilleur_artiste.iloc[:10]

spotify = pd.read_csv("~/Downloads/spotify_out.csv")
popularity = [100.0, 98.0, 97.0, 97.0, 97.0, 96.0, 96.0, 96.0, 95.0, 95.0]
artistes = ['Drake', 'XXXTENTACION', 'Ozuna', 'Ariana Grande', 'Queen', 'Travis Scott', 'Khalid', 'Post Malone', 'Cardi B', 'Nicki Minaj']

plt.figure(figsize=(20,20))
sns.barplot(dix_meilleurs['occurence_artiste'], dix_meilleurs['artiste'] )
plt.title("Artistes ayant la meilleur côte le plus dans le billboard")
plt.xlabel("Occurences")
plt.ylabel("Artistes")

plt.figure(figsize=(20,20))
sns.barplot(popularity, artistes )
plt.title("Artistes ayant la meilleur côte sur spotify")
plt.xlabel("Popularite")
plt.ylabel("Artistes")

plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-1-836dc308d2de> in <module>()
#      15 dix_meilleurs = meilleur_artiste.iloc[:10]
#      16
# ---> 17 spotify = pd.read_csv("~/Downloads/spotify_out.csv")
#      18 popularity = [100.0, 98.0, 97.0, 97.0, 97.0, 96.0, 96.0, 96.0, 95.0, 95.0]
#      19 artistes = ['Drake', 'XXXTENTACION', 'Ozuna', 'Ariana Grande', 'Queen', 'Travis Scott', 'Khalid', 'Post Malone', 'Cardi B', 'Nicki Minaj']
#
# /anaconda3/lib/python3.6/site-packages/pandas/io/parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, skipfooter, doublequote, delim_whitespace, low_memory, memory_map, float_precision)
#     676                     skip_blank_lines=skip_blank_lines)
#     677
# --> 678         return _read(filepath_or_buffer, kwds)
#     679
#     680     parser_f.__name__ = name
#
# /anaconda3/lib/python3.6/site-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     438
#     439     # Create the parser.
# --> 440     parser = TextFileReader(filepath_or_buffer, **kwds)
#     441
#     442     if chunksize or iterator:
#
# /anaconda3/lib/python3.6/site-packages/pandas/io/parsers.py in __init__(self, f, engine, **kwds)
#     785             self.options['has_index_names'] = kwds['has_index_names']
#     786
# --> 787         self._make_engine(self.engine)
#     788
#     789     def close(self):
#
# /anaconda3/lib/python3.6/site-packages/pandas/io/parsers.py in _make_engine(self, engine)
#    1012     def _make_engine(self, engine='c'):
#    1013         if engine == 'c':
# -> 1014             self._engine = CParserWrapper(self.f, **self.options)
#    1015         else:
#    1016             if engine == 'python':
#
# /anaconda3/lib/python3.6/site-packages/pandas/io/parsers.py in __init__(self, src, **kwds)
#    1706         kwds['usecols'] = self.usecols
#    1707
# -> 1708         self._reader = parsers.TextReader(src, **kwds)
#    1709
#    1710         passed_names = self.names is None
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._setup_parser_source()
#
# FileNotFoundError: File b'/Users/stephanetram/Downloads/spotify_out.csv' does not exist
